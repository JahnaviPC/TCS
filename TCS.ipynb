# %% [markdown]
# <a href="https://colab.research.google.com/github/JahnaviPC/TCS/blob/main/TCS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division
import numpy as np
import os
import glob
from random import *
from PIL import Image
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.image as mpimg
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Lambda, ELU, Activation, BatchNormalization
from keras.layers.convolutional import Convolution2D, Cropping2D, ZeroPadding2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD, Adam, RMSprop
from google.colab import drive

# %%
drive.mount('/content/gdrive')
d = {}
from subprocess import check_output
with open('/content/gdrive/My Drive/tcs/formss.txt') as f:
  for line in f:
    key = line.split(' ')[0]
    writer = line.split(' ')[1]
    d[key] = writer
print(len(d.keys()))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 1539

# %%
tmp = []
target_list = []
path_to_files = os.path.join('gdrive/My Drive/tcs/data_subset/data_subset','*')
for filename in sorted(glob.glob(path_to_files)):    
    tmp.append(filename)
    image_name = filename.split('/')[-1]
    file, ext = os.path.splitext(image_name)
    parts = file.split('-')
    print(parts)
    form = parts[0] + '-' + parts[1]
    
    for key in d:
        if key == form:
            target_list.append(str(d[form]))

img_files = np.asarray(tmp)
img_targets = np.asarray(target_list)
print(img_files)
print(img_targets)
# Out:
# ['a01', '000u', 's00', '00']
# ['a01', '000u', 's00', '02']
# ['a01', '003u', 's00', '00']
# ['a01', '003u', 's00', '01']
# ['a01', '003u', 's00', '02']
# ['a01', '003u', 's01', '00']
# ['a01', '003u', 's01', '02']
# ['a01', '003u', 's01', '03']
# ['a01', '003u', 's02', '00']
# ['a01', '003u', 's02', '03']
# ['a01', '007u', 's01', '00']
# ['a01', '007u', 's02', '01']
# ['a01', '007u', 's02', '03']
# ['a01', '011u', 's00', '02']
# ['a01', '011u', 's00', '03']
# ['a01', '011u', 's00', '04']
# ['a01', '011u', 's01', '00']
# ['a01', '011u', 's01', '02']
# ['a01', '014u', 's04', '00']
# ['a01', '020u', 's02', '00']
# ['a01', '020u', 's02', '01']
# ['a01', '020u', 's02', '02']
# ['a01', '026u', 's00', '03']
# ['a01', '026u', 's01', '03']
# ['a01', '030u', 's00', '00']
# ['a01', '030u', 's02', '00']
# ['a01', '030u', 's04', '00']
# ['a01', '030u', 's04', '01']
# ['a01', '030u', 's05', '00']
# ['a01', '030u', 's06', '00']
# ['a01', '030u', 's06', '01']
# ['a01', '030u', 's06', '02']
# ['a01', '043u', 's01', '01']
# ['a01', '043u', 's01', '02']
# ['a01', '043u', 's02', '01']
# ['a01', '043u', 's03', '00']
# ['a01', '043u', 's03', '01']
# ['a01', '043u', 's04', '02']
# ['a01', '043u', 's04', '03']
# ['a01', '049u', 's00', '00']
# ['a01', '049u', 's00', '04']
# ['a01', '049u', 's01', '00']
# ['a01', '049u', 's02', '01']
# ['a01', '049x', 's00', '02']
# ['a01', '049x', 's00', '03']
# ['a01', '049x', 's01', '00']
# ['a01', '049x', 's01', '01']
# ['a01', '049x', 's01', '02']
# ['a01', '049x', 's01', '03']
# ['a01', '049x', 's02', '02']
# ['a01', '053u', 's01', '01']
# ['a01', '053u', 's01', '02']
# ['a01', '053u', 's02', '01']
# ['a01', '053u', 's03', '00']
# ['a01', '058u', 's00', '01']
# ['a01', '058u', 's00', '02']
# ['a01', '058u', 's01', '00']
# ['a01', '063u', 's03', '00']
# ['a01', '068u', 's00', '01']
# ['a01', '068u', 's00', '02']
# ['a01', '068u', 's01', '01']
# ['a01', '068u', 's02', '00']
# ['a01', '068u', 's02', '02']
# ['a01', '068u', 's02', '04']
# ['a01', '072u', 's01', '01']
# ['a01', '072u', 's02', '02']
# ['a01', '077u', 's00', '00']
# ['a01', '077u', 's01', '00']
# ['a01', '077u', 's03', '01']
# ['a01', '077u', 's03', '02']
# ['a01', '082u', 's01', '02']
# ['a01', '082u', 's02', '02']
# ['a01', '087u', 's02', '02']
# ['a01', '091u', 's00', '00']
# ['a01', '091u', 's01', '00']
# ['a01', '091u', 's01', '03']
# ['a01', '091u', 's01', '04']
# ['a01', '091u', 's02', '01']
# ['a01', '091u', 's03', '02']
# ['a01', '096u', 's01', '00']
# ['a01', '096u', 's02', '00']
# ['a01', '096u', 's02', '01']
# ['a01', '096u', 's04', '04']
# ['a01', '102u', 's00', '00']
# ['a01', '102u', 's00', '01']
# ['a01', '102u', 's03', '00']
# ['a01', '102u', 's03', '01']
# ['a01', '107u', 's01', '00']
# ['a01', '113u', 's00', '02']
# ['a01', '113u', 's01', '00']
# ['a01', '113u', 's01', '01']
# ['a01', '113u', 's02', '02']
# ['a01', '113u', 's02', '04']
# ['a01', '117u', 's01', '02']
# ['a01', '117u', 's03', '00']
# ['a01', '117u', 's03', '02']
# ['a01', '122u', 's00', '01']
# ['a01', '122u', 's01', '00']
# ['a01', '122u', 's02', '00']
# ['a01', '122u', 's04', '02']
# ['a01', '128u', 's00', '00']
# ['a01', '128u', 's01', '00']
# ['a01', '128u', 's01', '01']
# ['a01', '128u', 's01', '03']
# ['a01', '128u', 's02', '04']
# ['a01', '132u', 's00', '00']
# ['a01', '132u', 's00', '02']
# ['a01', '132u', 's01', '01']
# ['a01', '132u', 's01', '03']
# ['a01', '132u', 's02', '03']
# ['a01', '132x', 's00', '00']
# ['a01', '132x', 's00', '02']
# ['a01', '132x', 's01', '00']
# ['a01', '132x', 's02', '00']
# ['a02', '017', 's00', '00']
# ['a02', '017', 's01', '00']
# ['a02', '017', 's01', '03']
# ['a02', '020', 's00', '00']
# ['a02', '020', 's00', '02']
# ['a02', '020', 's02', '00']
# ['a02', '020', 's02', '02']
# ['a02', '024', 's00', '03']
# ['a02', '027', 's01', '01']
# ['a02', '027', 's03', '01']
# ['a02', '027', 's03', '04']
# ['a02', '032', 's00', '01']
# ['a02', '032', 's01', '00']
# ['a02', '032', 's01', '01']
# ['a02', '032', 's02', '00']
# ['a02', '032', 's02', '01']
# ['a02', '032', 's03', '01']
# ['a02', '037', 's03', '00']
# ['a02', '037', 's03', '03']
# ['a02', '042', 's00', '00']
# ['a02', '042', 's01', '00']
# ['a02', '042', 's01', '01']
# ['a02', '042', 's01', '03']
# ['a02', '090', 's00', '01']
# ['a02', '090', 's01', '01']
# ['a02', '090', 's01', '03']
# ['a02', '093', 's01', '00']
# ['a02', '093', 's03', '02']
# ['a02', '098', 's02', '00']
# ['a02', '098', 's02', '04']
# ['a02', '102', 's00', '00']
# ['a02', '102', 's00', '01']
# ['a02', '102', 's00', '02']
# ['a02', '102', 's01', '00']
# ['a02', '102', 's01', '01']
# ['a02', '102', 's02', '03']
# ['a02', '106', 's00', '03']
# ['a02', '106', 's01', '00']
# ['a02', '106', 's03', '01']
# ['a02', '111', 's00', '00']
# ['a02', '111', 's02', '01']
# ['a03', '047', 's01', '01']
# ['a03', '050', 's00', '01']
# ['a03', '050', 's02', '03']
# ['a03', '071', 's00', '05']
# ['a03', '071', 's00', '08']
# ['a03', '073', 's00', '01']
# ['a03', '073', 's01', '00']
# ['a03', '073', 's01', '03']
# ['a03', '073', 's01', '04']
# ['a03', '080', 's00', '01']
# ['a03', '080', 's00', '05']
# ['a03', '080', 's01', '03']
# ['a03', '089', 's00', '00']
# ['a05', '000', 's00', '01']
# ['a05', '000', 's00', '02']
# ['a05', '000', 's00', '03']
# ['a05', '000', 's02', '00']
# ['a05', '013', 's00', '00']
# ['a05', '013', 's00', '01']
# ['a05', '013', 's02', '02']
# ['a05', '013', 's02', '03']
# ['a05', '013', 's02', '04']
# ['a05', '017', 's00', '00']
# ['a05', '017', 's02', '04']
# ['a05', '017', 's03', '03']
# ['a05', '022', 's01', '02']
# ['a05', '025', 's00', '00']
# ['a05', '025', 's01', '00']
# ['a05', '029', 's00', '01']
# ['a05', '029', 's01', '00']
# ['a05', '029', 's03', '01']
# ['a05', '029', 's03', '02']
# ['a05', '039', 's00', '01']
# ['a05', '039', 's00', '02']
# ['a05', '039', 's01', '00']
# ['a05', '039', 's03', '00']
# ['a05', '039', 's03', '02']
# ['a05', '044', 's00', '02']
# ['a05', '044', 's01', '01']
# ['a05', '048', 's01', '00']
# ['a05', '048', 's02', '01']
# ['a05', '048', 's03', '03']
# ['a05', '048', 's03', '04']
# ['a05', '053', 's00', '00']
# ['a05', '053', 's00', '01']
# ['a05', '053', 's01', '01']
# ['a05', '053', 's02', '00']
# ['a05', '053', 's02', '02']
# ['a05', '053', 's03', '02']
# ['a05', '053', 's03', '03']
# ['a05', '053', 's03', '04']
# ['a05', '058', 's00', '00']
# ['a05', '058', 's01', '01']
# ['a05', '062', 's00', '01']
# ['a05', '069', 's01', '01']
# ['a05', '069', 's01', '02']
# ['a05', '069', 's02', '05']
# ['a05', '073', 's03', '00']
# ['a05', '073', 's03', '02']
# ['a05', '073', 's04', '01']
# ['a05', '073', 's05', '02']
# ['a05', '080', 's00', '04']
# ['a05', '080', 's00', '05']
# ['a05', '080', 's02', '00']
# ['a05', '084', 's01', '00']
# ['a05', '084', 's01', '02']
# ['a05', '089', 's02', '00 (1)']
# ['a05', '089', 's02', '00']
# ['a05', '089', 's02', '02 (1)']
# ['a05', '089', 's02', '02']
# ['a05', '089', 's03', '00 (1)']
# ['a05', '089', 's03', '00']
# ['a05', '094', 's01', '01 (1)']
# ['a05', '094', 's01', '01']
# ['a05', '094', 's01', '02 (1)']
# ['a05', '094', 's01', '02']
# ['a05', '094', 's03', '01 (1)']
# ['a05', '094', 's03', '01']
# ['a05', '094', 's03', '03']
# ['a05', '099', 's02', '02']
# ['a05', '099', 's03', '00']
# ['a05', '104', 's01', '02']
# ['a05', '104', 's02', '02 (1)']
# ['a05', '104', 's02', '02']
# ['a05', '104', 's02', '03 (1)']
# ['a05', '104', 's02', '03']
# ['a05', '113', 's00', '01']
# ['a05', '113', 's01', '04']
# ['a05', '116', 's00', '01']
# ['a05', '116', 's03', '02']
# ['a05', '121', 's00', '00']
# ['a05', '121', 's00', '01']
# ['a05', '121', 's02', '04']
# ['a05', '125', 's00', '00']
# ['a05', '125', 's01', '00']
# ['a05', '125', 's01', '04']
# ['a06', '124', 's00', '01']
# ['a06', '124', 's01', '00']
# ['a06', '124', 's02', '02']
# ['a06', '134', 's02', '00']
# ['a06', '141', 's00', '00']
# ['a06', '141', 's01', '01']
# ['a06', '141', 's01', '02']
# ['a06', '141', 's01', '03']
# ['a06', '141', 's03', '00']
# ['a06', '141', 's03', '01']
# ['a06', '147', 's00', '00']
# ['a06', '147', 's01', '00']
# ['a06', '147', 's02', '00']
# ['a06', '147', 's03', '00']
# ['a06', '157', 's01', '01']
# ['b05', '055', 's01', '00']
# ['b05', '055', 's01', '01']
# ['b05', '058', 's00', '00']
# ['b05', '058', 's01', '00']
# ['b05', '058', 's02', '00']
# ['b05', '058', 's02', '03']
# ['b05', '062', 's01', '02']
# ['b05', '062', 's02', '00']
# ['b05', '062', 's03', '00']
# ['b05', '067', 's00', '00']
# ['b05', '067', 's02', '00']
# ['b05', '067', 's02', '01']
# ['b05', '071', 's00', '00']
# ['b05', '071', 's01', '01']
# ['b06', '000', 's00', '01']
# ['b06', '000', 's01', '00']
# ['b06', '008', 's00', '01']
# ['b06', '012', 's00', '00']
# ['b06', '012', 's00', '02']
# ['b06', '012', 's01', '02']
# ['b06', '019', 's00', '04']
# ['b06', '019', 's01', '00']
# ['b06', '019', 's01', '01']
# ['b06', '019', 's01', '02']
# ['b06', '023', 's01', '02']
# ['b06', '023', 's02', '01']
# ['b06', '032', 's00', '00']
# ['b06', '032', 's02', '00']
# ['b06', '036', 's01', '00']
# ['b06', '036', 's01', '01']
# ['b06', '036', 's04', '00']
# ['b06', '036', 's04', '02']
# ['b06', '056', 's00', '01']
# ['b06', '056', 's01', '00']
# ['b06', '056', 's01', '01']
# ['b06', '056', 's01', '02']
# ['b06', '059', 's00', '00']
# ['b06', '059', 's01', '02']
# ['b06', '059', 's03', '03']
# ['b06', '064', 's01', '01']
# ['b06', '064', 's02', '00']
# ['b06', '064', 's02', '06']
# ['b06', '071', 's00', '00']
# ['b06', '071', 's01', '00 (1)']
# ['b06', '071', 's01', '00']
# ['gdrive/My Drive/tcs/data_subset/data_subset/a01-000u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-000u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-007u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-007u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-007u-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s00-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s00-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-014u-s04-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-020u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-020u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-020u-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-026u-s00-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-026u-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s04-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s04-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s05-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s06-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s06-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-030u-s06-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s04-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-043u-s04-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049u-s00-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s00-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-049x-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-053u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-053u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-053u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-053u-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-058u-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-058u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-058u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-063u-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-068u-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-068u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-068u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-068u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-068u-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-068u-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-072u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-072u-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-077u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-077u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-077u-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-077u-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-082u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-082u-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-087u-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-091u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-091u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-091u-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-091u-s01-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-091u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-091u-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-096u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-096u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-096u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-096u-s04-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-102u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-102u-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-102u-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-102u-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-107u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-113u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-113u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-113u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-113u-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-113u-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-117u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-117u-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-117u-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-122u-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-122u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-122u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-122u-s04-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-128u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-128u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-128u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-128u-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-128u-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132u-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132u-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132u-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132u-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132x-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132x-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132x-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-132x-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-017-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-017-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-017-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-020-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-020-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-020-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-020-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-024-s00-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-027-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-027-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-027-s03-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-032-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-032-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-032-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-032-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-032-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-032-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-037-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-037-s03-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-042-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-042-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-042-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-042-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-090-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-090-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-090-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-093-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-093-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-098-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-098-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-102-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-102-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-102-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-102-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-102-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-102-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-106-s00-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-106-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-106-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-111-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a02-111-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-047-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-050-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-050-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-071-s00-05.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-071-s00-08.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-073-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-073-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-073-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-073-s01-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-080-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-080-s00-05.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-080-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a03-089-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-000-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-000-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-000-s00-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-000-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-013-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-013-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-013-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-013-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-013-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-017-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-017-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-017-s03-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-022-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-025-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-025-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-029-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-029-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-029-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-029-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-039-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-039-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-039-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-039-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-039-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-044-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-044-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-048-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-048-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-048-s03-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-048-s03-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s03-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-053-s03-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-058-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-058-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-062-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-069-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-069-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-069-s02-05.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-073-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-073-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-073-s04-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-073-s05-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-080-s00-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-080-s00-05.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-080-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-084-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-084-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-089-s02-00 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-089-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-089-s02-02 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-089-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-089-s03-00 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-089-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s01-01 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s01-02 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s03-01 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-094-s03-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-099-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-099-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-104-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-104-s02-02 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-104-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-104-s02-03 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-104-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-113-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-113-s01-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-116-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-116-s03-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-121-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-121-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-121-s02-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-125-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-125-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a05-125-s01-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-124-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-124-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-124-s02-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-134-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-141-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-141-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-141-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-141-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-141-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-141-s03-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-147-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-147-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-147-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-147-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a06-157-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-055-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-055-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-058-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-058-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-058-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-058-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-062-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-062-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-062-s03-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-067-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-067-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-067-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-071-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b05-071-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-000-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-000-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-008-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-012-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-012-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-012-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-019-s00-04.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-019-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-019-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-019-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-023-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-023-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-032-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-032-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-036-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-036-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-036-s04-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-036-s04-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-056-s00-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-056-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-056-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-056-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-059-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-059-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-059-s03-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-064-s01-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-064-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-064-s02-06.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-071-s00-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-071-s01-00 (1).png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/b06-071-s01-00.png']
# ['000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '025' '025' '025' '025' '025' '025'
#  '025' '025' '025' '025' '025' '025' '025' '025' '025' '025' '025' '026'
#  '026' '026' '026' '026' '026' '026' '026' '026' '026' '026' '026' '026'
#  '037' '037' '037' '037' '037' '037' '037' '037' '037' '037' '037' '037'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000'
#  '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '000' '085'
#  '085' '085' '085' '085' '085' '085' '085' '085' '085' '085' '085' '085'
#  '085' '085' '118' '118' '118' '118' '118' '118' '118' '118' '118' '118'
#  '118' '118' '118' '118' '123' '123' '125' '126' '126' '126' '128' '128'
#  '128' '128' '123' '123' '130' '130' '126' '126' '126' '126' '125' '125'
#  '125' '125' '130' '130' '130' '133' '133' '133' '128' '128' '128']

# %%
# Visualizing the data
for filename in img_files[6:15]:
    img=mpimg.imread(filename)
    plt.figure(figsize=(10,10))
    plt.imshow(img, cmap ='gray')

# %%
# Label Encode writer names for one hot encoding later
encoder = LabelEncoder()
encoder.fit(img_targets)
encoded_Y = encoder.transform(img_targets)

print(img_files[6:15], img_targets[6:15], encoded_Y[6:15])
# Out:
# ['gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s01-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s01-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s02-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-003u-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-007u-s01-00.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-007u-s02-01.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-007u-s02-03.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s00-02.png'
#  'gdrive/My Drive/tcs/data_subset/data_subset/a01-011u-s00-03.png'] ['000' '000' '000' '000' '000' '000' '000' '000' '000'] [0 0 0 0 0 0 0 0 0]

# %%
from sklearn.model_selection import train_test_split
train_files, rem_files, train_targets, rem_targets = train_test_split(
        img_files, encoded_Y, train_size=0.66, random_state=52, shuffle= True)

validation_files, test_files, validation_targets, test_targets = train_test_split(
        rem_files, rem_targets, train_size=0.5, random_state=22, shuffle=True)

print(train_files.shape, validation_files.shape, test_files.shape)
print(train_targets.shape, validation_targets.shape, test_targets.shape)
# Out:
# (205,) (53,) (53,)
# (205,) (53,) (53,)

# %%
batch_size = 16
num_classes = 50


def generate_data(samples, target_files,  batch_size=batch_size, factor = 0.1 ):
    num_samples = len(samples)
    from sklearn.utils import shuffle
    while 1: # Loop forever so the generator never terminates
 
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset:offset+batch_size]
            batch_targets = target_files[offset:offset+batch_size]

            images = []
            targets = []
            for i in range(len(batch_samples)):
                batch_sample = batch_samples[i]
                batch_target = batch_targets[i]
                im = Image.open(batch_sample)
                cur_width = im.size[0]
                cur_height = im.size[1]

                
                height_fac = 113 / cur_height

                new_width = int(cur_width * height_fac)
                size = new_width, 113

                imresize = im.resize((size), Image.ANTIALIAS)  
                now_width = imresize.size[0]
                now_height = imresize.size[1]
                

                avail_x_points = list(range(0, now_width - 113 ))

            
                pick_num = int(len(avail_x_points)*factor)

              
                random_startx = sample(avail_x_points,  pick_num)

                for start in random_startx:
                    imcrop = imresize.crop((start, 0, start+113, 113))
                    images.append(np.asarray(imcrop))
                    targets.append(batch_target)

            X_train = np.array(images)
            y_train = np.array(targets)

           
            X_train = X_train.reshape(X_train.shape[0], 113, 113, 1)
           
            X_train = X_train.astype('float32')
            X_train /= 255

         
            y_train = to_categorical(y_train, num_classes)

            yield shuffle(X_train, y_train)

# %%
# Generate data for training and validation
train_generator = generate_data(train_files, train_targets, batch_size=batch_size, factor = 0.3)
validation_generator = generate_data(validation_files, validation_targets, batch_size=batch_size, factor = 0.3)
test_generator = generate_data(test_files, test_targets, batch_size=batch_size, factor = 0.1)

# %%
def resize_image(image):
    import tensorflow as tf
    return tf.image.resize_images(image,[56,56])


row, col, ch = 113, 113, 1

model = Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=(row, col, ch)))


#model.add(Lambda(resize_image)) 
#model.add(Lambda(lambda x: resize_image))


model.add(Convolution2D(filters= 32, kernel_size =(5,5), strides= (2,2), padding='same', name='conv1')) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool1'))

model.add(Convolution2D(filters= 64, kernel_size =(3,3), strides= (1,1), padding='same', name='conv2'))  
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool2'))

model.add(Convolution2D(filters= 128, kernel_size =(3,3), strides= (1,1), padding='same', name='conv3')) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool3'))


model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(512, name='dense1'))  

model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256, name='dense2'))  
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes,name='output'))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 115, 115, 1)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 58, 58, 32)        832
# _________________________________________________________________
# activation (Activation)      (None, 58, 58, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 29, 29, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 29, 29, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense1 (Dense)               (None, 512)               3211776
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 50)                12850
# _________________________________________________________________
# activation_5 (Activation)    (None, 50)                0
# =================================================================
# Total params: 3,449,138
# Trainable params: 3,449,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Saving the model and weights into GDrive

from keras.models import model_from_json   
# serialize model to JSON
model_json = model.to_json()
with open("gdrive/My Drive/model/HTR_Model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("gdrive/My Drive/model/HTR_model_weights.hdf5")
print("Saved model to GDrive")
# Out:
# Saved model to GDrive

# %%
import tensorflow as tf
json_file = open("gdrive/My Drive/model/HTR_Model.json", 'r')
loaded_model_json = json_file.read()
json_file.close()
l_model = tf.keras.models.model_from_json(loaded_model_json)
# load weights into new model
l_model.load_weights("gdrive/My Drive/model/HTR_model_weights.hdf5")
print("Loaded model from Gdrive")
# Out:
# Loaded model from Gdrive

# %%
model.save("gdrive/My Drive/model/HTR_model.hdf5")
print("Saved Keras Model")
# Out:
# Saved Keras Model

# %%
#from keras.models import load_model
# load model
from tensorflow import keras
loaded_model = keras.models.load_model("gdrive/My Drive/model/HTR_model.hdf5", custom_objects=None, compile=True, options=None)
print("Loaded the Keras Model")
# Out:
# Loaded the Keras Model

# %%
print(loaded_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 115, 115, 1)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 58, 58, 32)        832
# _________________________________________________________________
# activation (Activation)      (None, 58, 58, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 29, 29, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 29, 29, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense1 (Dense)               (None, 512)               3211776
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 50)                12850
# _________________________________________________________________
# activation_5 (Activation)    (None, 50)                0
# =================================================================
# Total params: 3,449,138
# Trainable params: 3,449,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
images = []
for filename in test_files[:50]:
    im = Image.open(filename)
    cur_width = im.size[0]
    cur_height = im.size[1]

   
    height_fac = 113 / cur_height

    new_width = int(cur_width * height_fac)
    size = new_width, 113

    imresize = im.resize((size), Image.ANTIALIAS)  
    now_width = imresize.size[0]
    now_height = imresize.size[1]


    avail_x_points = list(range(0, now_width - 113 ))

    
    factor = 0.1
    pick_num = int(len(avail_x_points)*factor)
    
    random_startx = sample(avail_x_points,  pick_num)

    for start in random_startx:
        imcrop = imresize.crop((start, 0, start+113, 113))
        images.append(np.asarray(imcrop))
        
    X_test = np.array(images)
    
    X_test = X_test.reshape(X_test.shape[0], 113, 113, 1)
   
    X_test = X_test.astype('float32')
    X_test /= 255
    shuffle(X_test)

print(X_test.shape)
# Out:
# (9237, 113, 113, 1)

# %%
predictions = loaded_model.predict(X_test, verbose =1)

print(predictions.shape)
predicted_writer = []
for pred in predictions:
    predicted_writer.append(np.argmax(pred))
print(len(predicted_writer))
# Out:
# 289/289 [==============================] - 16s 55ms/step
# (9237, 50)
# 9237

# %%
writer_number = 18
total_images =10
counter = 0
for i in range(len(predicted_writer)//10):
    if predicted_writer[i] == writer_number:
        image = X_test[i].squeeze()
        plt.figure(figsize=(2,2))
        plt.imshow(image, cmap ='gray')

# %%
writer_number = 18
total_images =10
counter = 0
print("JAHNAVI P C")
for i in range(len(predicted_writer)//10):
    if predicted_writer[i] == writer_number:
        image = X_test[i].squeeze()
        plt.figure(figsize=(2,2))
        plt.imshow(image, cmap ='gray')
        plt.show()
# Out:
# JAHNAVI P C
